# %% [markdown]
# # Speed dating experiment
#
# ## What influences love at first sight? Or, at least, love in the first four minutes?
#
# The [dataset](https://www.kaggle.com/annavictoria/speed-dating-experiment) was compiled by Columbia Business School professors Ray Fisman and Sheena Iyengar for their paper *Gender Differences in Mate Selection: Evidence From a Speed Dating Experiment*.
#
# Data was gathered from participants in experimental speed dating events from 2002-2004. During the events, the attendees would have a four minute "first date" with every other participant of the opposite sex. At the end of their four minutes, participants were asked if they would like to see their date again. They were also asked to rate their date on six attributes: Attractiveness, Sincerity, Intelligence, Fun, Ambition, and Shared Interests.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats import gaussian_kde
import statsmodels.api as sm
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, classification_report, roc_curve, roc_auc_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Hiding warnings for better appearance (this was added after checking all warnings)
import warnings
warnings.filterwarnings(action = "ignore")

# %% [markdown]
# ### Style

# %%
blue = '#1e1eff'
purple = '#7c7bfb'
salmon = '#ff9696'
red = '#ff5a5a'
pie_chart_colors = [red, blue]
cmap = sns.color_palette("vlag", as_cmap=True)

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# ### Loading data

# %%
data = pd.read_csv('dataset.csv')
data = data.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## Hypothesis evaluation

# %% [markdown]
# Hypothesis 1 - It is possible to predict participants' match based on their personal characteristics and interests.
#
# Hypothesis 2 - It is possible to predict participant's preference on partner's intelligence based on the participant's personal characteristics.
#
# Hypothesis 3 - It is possible to predict how much the participant likes their date and which attributes have the biggest influence on it based on the date participants' personal characteristics.
#
# Hypothesis 4 - It is true that techinal eingineers tend to date medics.
#
# Hypothesis 5 - sports oriented women are looking for sports oriented men.

# %% [markdown]
# ### Hypothesis 1
# It is possible to predict participants' match based on their personal characteristics and interests.

# %%
data_1 = data.copy()

data_1 = data_1[[
    'match',
    'samerace',
    'int_corr',
    'attr_me', 'sinc_me', 'fun_me', 'intel_me', 'amb_me',
    'attr_me_partners', 'sinc_me_partners', 'fun_me_partners', 'intel_me_partners', 'amb_me_partners'
]].dropna()


data_x = data_1.drop(columns=['match'])
data_y = data_1['match']

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.20, random_state=42 )

# %% [markdown]
# #### K-NN algorithm

# %% [markdown]
# ##### Looking for the best number of classes

# %%
auc_score = []
for i in range(1,30):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict_proba(X_test)
    pred_i = pred_i[:, 1]
    auc_score.append( roc_auc_score(y_test,pred_i) )
    
plt.plot(range(1,30), auc_score, color='blue', linestyle='dashed', marker='o',
 markerfacecolor='red', markersize=10)
plt.title('auc_score vs. K Value')
plt.xlabel('K')
plt.ylabel('auc_score')
# Out:
# Text(0, 0.5, 'auc_score')

# %% [markdown]
# We see that the best option would have 1 cluster - that doesnt make sense so we will take 3 clusters in further training

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
pred_i = knn.predict(X_test)

print(f'Area under ROC curve is {roc_auc_score(y_test,pred_i)}')
# Out:
# Area under ROC curve is 0.5345238784370479

# %% [markdown]
# ##### ROC curve

# %%
# https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/

def plot_curve(_probs, y_test, model_name):
    _probs = _probs[:, 1]
    ns_probs = [0 for _ in range(len(y_test))]

    # calculate scores
    auc = roc_auc_score(y_test, _probs)
    ns_auc = roc_auc_score(y_test, ns_probs)

    print('Logistic: ROC AUC=%.3f' % (auc))

    # calculate roc curves
    _fpr, _tpr, _ = roc_curve(y_test, _probs)
    ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

    # plot the roc curve for the model
    plt.plot(_fpr, _tpr, marker='.', label=model_name, color='red')
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

    plt.legend()
    plt.show()

# %%
plot_curve(knn.predict_proba(X_test), y_test, 'kNN')
# Out:
# Logistic: ROC AUC=0.567

# %%
print(f'Silhouette_score is {silhouette_score(X_test,pred_i)}')
# Out:
# Silhouette_score is -0.017570582226659692

# %% [markdown]
# ##### Confusion matrix

# %%
df_cm = pd.DataFrame(confusion_matrix(y_test, pred_i))
sns.heatmap(df_cm, annot=True, fmt="d", cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, pred_i))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.89      1382
#            1       0.28      0.13      0.18       250
#
#     accuracy                           0.81      1632
#    macro avg       0.57      0.53      0.54      1632
# weighted avg       0.77      0.81      0.79      1632

# %% [markdown]
# ##### Cross validation

# %%
results = []
for i in range(100):
    
    X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.20 )
    
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)

    results.append(roc_auc_score(y_test,pred_i))
    

pd.DataFrame(results).describe()
# Out:
#                 0
# count  100.000000
# mean     0.523455
# std      0.009343
# min      0.504412
# 25%      0.517253
# 50%      0.522764
# 75%      0.529020
# max      0.546651

# %% [markdown]
# #### Decision tree

# %% [markdown]
# ##### Grid search params

# %%
criterion = ["gini", "entropy"]

# Number of features to consider at every split
max_features = ["auto", "log2"]

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(3, 20, num = 10)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 4, 6, 8, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 3]

param_grid = {
    "criterion": criterion,
    "max_features": max_features,
    "max_depth": max_depth,
    "min_samples_split": min_samples_split,
    "min_samples_leaf": min_samples_leaf
}

# %%
dtree_model = DecisionTreeClassifier()

dtree_gscv = GridSearchCV(dtree_model, param_grid, cv=5)
dtree_gscv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 6, 8, 10, 12, 14, 16, 18, 20,
#                                        None],
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 4, 6, 8, 10]})

# %%
params = dtree_gscv.best_params_
dtree_best_model = DecisionTreeClassifier(**params)
dtree_best_model.fit(X_train,y_train)
pred_i = dtree_best_model.predict(X_test)

print(f'Area under ROC curve is {roc_auc_score(y_test,pred_i)}')
# Out:
# Area under ROC curve is 0.5

# %%
plot_curve(dtree_best_model.predict_proba(X_test), y_test, 'Decision tree')
# Out:
# Logistic: ROC AUC=0.526

# %%
df_cm = pd.DataFrame(confusion_matrix(y_test, pred_i))
sns.heatmap(df_cm, annot=True, fmt="d", cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,pred_i))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      1374
#            1       0.00      0.00      0.00       258
#
#     accuracy                           0.84      1632
#    macro avg       0.42      0.50      0.46      1632
# weighted avg       0.71      0.84      0.77      1632

# %% [markdown]
# ### With hobbies

# %%
data_1 = data.copy()

data_1 = data_1[[
    'match',
    'samerace',
    'int_corr',
    'attr_me', 'sinc_me', 'fun_me', 'intel_me', 'amb_me',
    'attr_me_partners', 'sinc_me_partners', 'fun_me_partners', 'intel_me_partners', 'amb_me_partners',
    
    'sports','tvsports','exercise','dining','museums','art','hiking','gaming','clubbing',
    'reading','tv','theater','movies','concerts','music','shopping','yoga',
    
    'sports_partners','tvsports_partners','exercise_partners','dining_partners','museums_partners','art_partners','hiking_partners',
    'gaming_partners','clubbing_partners',
    'reading_partners','tv_partners','theater_partners','movies_partners','concerts_partners',
    'music_partners','shopping_partners','yoga_partners',
    
]].dropna()


data_x = data_1.drop(columns=['match'])
data_y = data_1['match']

X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.20, random_state=42)

# %% [markdown]
# ##### Looking for the best number of classes

# %%
auc_score = []

for i in range(1,30):    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict_proba(X_test)
    pred_i = pred_i[:, 1]
    auc_score.append( roc_auc_score(y_test,pred_i) )
    
plt.plot(range(1,30),auc_score,color='blue', linestyle='dashed', marker='o',
 markerfacecolor='red', markersize=10)
plt.title('auc_score vs. K Value')
plt.xlabel('K')
plt.ylabel('auc_score')
# Out:
# Text(0, 0.5, 'auc_score')

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
pred_i = knn.predict(X_test)

print(f'Area under ROC curve is {roc_auc_score(y_test,pred_i)}')
# Out:
# Area under ROC curve is 0.5363531114327063

# %% [markdown]
# ##### ROC curve

# %%
plot_curve(knn.predict_proba(X_test), y_test, 'kNN')
# Out:
# Logistic: ROC AUC=0.609

# %%
print(f'Silhouette_score is {silhouette_score(X_test,pred_i)}')
# Out:
# Silhouette_score is 0.0015311996462809743

# %% [markdown]
# ##### Confusion matrix

# %%
df_cm = pd.DataFrame(confusion_matrix(y_test, pred_i))
sns.heatmap(df_cm, annot=True, fmt="d", cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, pred_i))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      1382
#            1       0.27      0.14      0.19       250
#
#     accuracy                           0.81      1632
#    macro avg       0.57      0.54      0.54      1632
# weighted avg       0.77      0.81      0.78      1632

# %% [markdown]
# #### Decision tree

# %% [markdown]
# ##### Grid search params

# %%
dtree_model = DecisionTreeClassifier()

dtree_gscv = GridSearchCV(dtree_model, param_grid, cv=5)
dtree_gscv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 6, 8, 10, 12, 14, 16, 18, 20,
#                                        None],
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 4, 6, 8, 10]})

# %%
params = dtree_gscv.best_params_
dtree_best_model = DecisionTreeClassifier(**params)
dtree_best_model.fit(X_train,y_train)
pred_i = dtree_best_model.predict(X_test)

print(f'Area under ROC curve is {roc_auc_score(y_test,pred_i)}')
# Out:
# Area under ROC curve is 0.5

# %%
plot_curve(dtree_best_model.predict_proba(X_test), y_test, 'Decision tree')
# Out:
# Logistic: ROC AUC=0.549

# %%
df_cm = pd.DataFrame(confusion_matrix(y_test, pred_i))
sns.heatmap(df_cm, annot=True, fmt="d", cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,pred_i))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1382
#            1       0.00      0.00      0.00       250
#
#     accuracy                           0.85      1632
#    macro avg       0.42      0.50      0.46      1632
# weighted avg       0.72      0.85      0.78      1632

# %% [markdown]
# ### Hypothesis 2
#
# It is possible to predict participant's preference on partner's intelligence based on the participant's personal characteristics.

# %%
data_2 = data.copy()

# %%
df_personal = data_2[[
  'attr_me', 'sinc_me', 'fun_me', 'intel_me', 'amb_me', 'iid', 'pid', 'match', 'intel_me_partners', 'dec', 'dec_partner',
    'career','career_c'
]]

# %%
df_personal = df_personal[df_personal['match']==1]

df_personal.dropna(inplace=True)

df_personal_y = df_personal['intel_me_partners']
df_personal_x = df_personal.drop(columns=['intel_me_partners'])

# %% [markdown]
# #### Is there realtionship between our features and predicted value ?

# %%
for attr in df_personal.columns[:5]:
    x = df_personal[attr]
    y = df_personal['intel_me_partners']

    xy = np.vstack([x,y])
    z = gaussian_kde(xy)(xy)

    fig, ax = plt.subplots()
    ax.scatter(x, y, c=z, s=100)
    plt.title(attr + ' vs. partner\'s intelligence')
    plt.xlabel(attr)
    plt.ylabel('partner\'s intelligence')
    plt.show()

# %% [markdown]
# #### Poisson regression

# %%
X_train, X_test, y_train, y_test = train_test_split(df_personal_x, df_personal_y, test_size=0.20, random_state=42 )

# %%
X_train[['attr_me','intel_me','sinc_me','amb_me']].describe()
# Out:
#            attr_me     intel_me      sinc_me       amb_me
# count  1052.000000  1052.000000  1052.000000  1052.000000
# mean      7.199620     8.405894     8.270913     7.623574
# std       1.360752     1.012615     1.414143     1.684127
# min       3.000000     3.000000     2.000000     2.000000
# 25%       6.000000     8.000000     8.000000     7.000000
# 50%       7.000000     8.000000     8.000000     8.000000
# 75%       8.000000     9.000000     9.000000     9.000000
# max      10.000000    10.000000    10.000000    10.000000

# %% [markdown]
# Almost all of our data have mean around 7-8 and variance logicly must be lower, because we have data in scale 1-10. As we can see in the table above, variances are about 1-2. Poissonal data should have equal mean and variance, thats something that is unreal in our case.

# %%
gamma_model = sm.GLM(y_train,X_train[['attr_me','intel_me','sinc_me','amb_me']], family=sm.families.Poisson())

gamma_results = gamma_model.fit()

print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:      intel_me_partners   No. Observations:                 1052
# Model:                            GLM   Df Residuals:                     1048
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2395.1
# Date:                Sun, 27 Mar 2022   Deviance:                       603.35
# Time:                        23:29:00   Pearson chi2:                     644.
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# attr_me        0.0304      0.009      3.466      0.001       0.013       0.048
# intel_me       0.1437      0.010     13.783      0.000       0.123       0.164
# sinc_me        0.0585      0.008      7.487      0.000       0.043       0.074
# amb_me         0.0224      0.007      3.167      0.002       0.009       0.036
# ==============================================================================

# %%
y_pred = gamma_results.predict(X_test[['attr_me','intel_me','sinc_me','amb_me']])

mse = mean_squared_error(y_test,y_pred)
rmse = math.sqrt(mse/len(y_pred))

print(rmse)
# Out:
# 0.12603986776910306

# %% [markdown]
# #### Negative Binomial regression

# %%
X_train, X_test, y_train, y_test = train_test_split(df_personal_x, df_personal_y, test_size=0.20, random_state=42 )

# %%
gamma_model = sm.GLM(y_train,X_train[['attr_me','intel_me','sinc_me','amb_me']], family=sm.families.NegativeBinomial())

gamma_results = gamma_model.fit()

print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:      intel_me_partners   No. Observations:                 1052
# Model:                            GLM   Df Residuals:                     1048
# Model Family:        NegativeBinomial   Df Model:                            3
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3379.3
# Date:                Sat, 26 Mar 2022   Deviance:                       68.101
# Time:                        23:22:50   Pearson chi2:                     75.4
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# attr_me        0.0398      0.026      1.508      0.131      -0.012       0.091
# intel_me       0.1411      0.031      4.565      0.000       0.081       0.202
# sinc_me        0.0565      0.023      2.494      0.013       0.012       0.101
# amb_me         0.0243      0.021      1.155      0.248      -0.017       0.066
# ==============================================================================

# %%
y_pred = gamma_results.predict(X_test[['attr_me','intel_me','sinc_me','amb_me']])

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = math.sqrt(mse/len(y_pred))

# %%
print(rmse)
# Out:
# 0.13481625394412491

# %% [markdown]
# #### Are there any error, outliers, specific points... - NO

# %%
df_pred = X_train[['attr_me','intel_me','sinc_me','amb_me']]

# %%
df_pred.describe()
# Out:
#            attr_me     intel_me      sinc_me       amb_me
# count  1052.000000  1052.000000  1052.000000  1052.000000
# mean      7.199620     8.405894     8.270913     7.623574
# std       1.360752     1.012615     1.414143     1.684127
# min       3.000000     3.000000     2.000000     2.000000
# 25%       6.000000     8.000000     8.000000     7.000000
# 50%       7.000000     8.000000     8.000000     8.000000
# 75%       8.000000     9.000000     9.000000     9.000000
# max      10.000000    10.000000    10.000000    10.000000

# %%
df_pred.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.catplot( kind="violin", data=df_pred)

# %%
x = y_test
y = y_pred

xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=100)

plt.title('real vs. predicted partner\'s intelligence')
plt.xlabel('real partner\'s intelligence')
plt.ylabel('predicted partner\'s intelligence')
plt.show()

# %%
df_personal[['career_c_partners']]
# Out:
#       career_c_partners
# 30                  2.0
# 31                  1.0
# 32                  1.0
# 33                  1.0
# 34                  1.0
# ...                 ...
# 8373               11.0
# 8374               11.0
# 8375               11.0
# 8376                5.0
# 8377               10.0
#
# [8094 rows x 1 columns]

# %% [markdown]
# ### Hypothesis 3
# It is possible to predict how much the participant likes their date and which attributes have the biggest influence on it based on the date participants' personal characteristics.

# %%
data_3 = data.copy()

data_3 = data_3[[
    'attr_me_partners', 'sinc_me_partners', 'fun_me_partners', 'intel_me_partners', 'amb_me_partners',
    'iid_like_pid'
   
]].dropna()

# %%
data_x = data_3.drop(columns="iid_like_pid")
data_y = data_3['iid_like_pid']

# %% [markdown]
# # Is there a relationship between predicted variable and features ?

# %%
for attr in ['attr_me_partners', 'sinc_me_partners', 'fun_me_partners', 'intel_me_partners', 'amb_me_partners']:
    x = data_x[attr]
    y = data_y

    xy = np.vstack([x,y])
    z = gaussian_kde(xy)(xy)

    fig, ax = plt.subplots()
    ax.scatter(x, y, c=z, s=100)
    plt.title(attr + ' vs. my sympathy to other')
    plt.xlabel(attr)
    plt.ylabel('Sympathy')
    plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.20, random_state=42 )

# %%
gamma_model = sm.GLM(y_train,X_train, family=sm.families.Poisson())

gamma_results = gamma_model.fit()

print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           iid_like_pid   No. Observations:                 6425
# Model:                            GLM   Df Residuals:                     6420
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -14268.
# Date:                Sun, 27 Mar 2022   Deviance:                       5278.7
# Time:                        23:51:57   Pearson chi2:                 5.13e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# attr_me_partners      0.0326      0.004      7.603      0.000       0.024       0.041
# sinc_me_partners      0.0498      0.004     13.927      0.000       0.043       0.057
# fun_me_partners       0.0452      0.004     11.935      0.000       0.038       0.053
# intel_me_partners     0.0893      0.005     19.384      0.000       0.080       0.098
# amb_me_partners       0.0043      0.003      1.312      0.189      -0.002       0.011
# =====================================================================================

# %%
y_pred = gamma_results.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
rmse = math.sqrt(mse/len(y_pred))

# %%
print(rmse)
# Out:
# 0.05417125410227247

# %%
y_pred.describe()
# Out:
# count    1607.000000
# mean        5.988785
# std         1.122494
# min         2.268779
# 25%         5.260413
# 50%         5.940950
# 75%         6.643370
# max         9.126385
# dtype: float64

# %%
df_pred = X_train[['attr_me_partners', 'sinc_me_partners', 'fun_me_partners', 'intel_me_partners', 'amb_me_partners']]

# %%
df_pred.describe()
# Out:
#        attr_me_partners  sinc_me_partners  fun_me_partners  intel_me_partners  \
# count       6425.000000       6425.000000      6425.000000        6425.000000
# mean           7.085603          8.299455         7.700389           8.409805
# std            1.399103          1.415635         1.569193           1.080074
# min            2.000000          2.000000         2.000000           3.000000
# 25%            6.000000          8.000000         7.000000           8.000000
# 50%            7.000000          8.000000         8.000000           8.000000
# 75%            8.000000          9.000000         9.000000           9.000000
# max           10.000000         10.000000        10.000000          10.000000
#
#        amb_me_partners
# count      6425.000000
# mean          7.587704
# std           1.785546
# min           2.000000
# 25%           7.000000
# 50%           8.000000
# 75%           9.000000
# max          10.000000

# %%
df_pred.boxplot()

# %%
sns.catplot( kind="violin", data=df_pred)

# %%
x = y_test
y = y_pred

xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=100)

plt.title('real vs. predicted partner\'s intelligence')
plt.xlabel('real partner\'s intelligence')
plt.ylabel('predicted partner\'s intelligence')
plt.show()

# %% [markdown]
# # Evaluation

# %%
df_ = pd.DataFrame({'real_like': np.array(y_test), 'predicted_like': np.array(y_pred)})

plt.plot(np.array(df_['real_like'][:100]), color = 'blue', label = 'real')
plt.plot(np.array(df_['predicted_like'][:100]), color = 'red', label = 'predicted')
plt.title('Prediction of how much participant likes their date (random 100 samples)')
plt.xlabel('Index of participant')
plt.ylabel('Level of like')
plt.legend()
plt.show()

# %%
x = y_test
y = y_pred

xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
scatter = ax.scatter(x, y, c=z, s=100)

plt.title('Prediction of how much participant likes their date')
plt.xlabel('Real level of like')
plt.ylabel('Predicted level of like')
plt.show()

# %% [markdown]
# # Medicky a inzinieri

# %%
enc = OneHotEncoder()

# %% [markdown]
# ### Model formalism

# %%
data_4 = data.copy()

# %%
df_personal = data_4[[
   'iid', 'pid', 'match', 'dec', 'career_c', 'career_c_partners', 'gender', 'gender_partners'
]]
df_personal.dropna(inplace=True)

# %%
enc_df_partners = pd.DataFrame(enc.fit_transform(df_personal[['career_c_partners']]).toarray())
enc_df_partners = enc_df_partners.add_suffix('_partners')

enc_df_me = pd.DataFrame(enc.fit_transform(df_personal[['career_c']]).toarray())
enc_df_me = enc_df_me.add_suffix('_me')

# %%
df_personal = df_personal.join(enc_df_partners,lsuffix='_partners')
df_personal = df_personal.join(enc_df_me,rsuffix='_me')

# %% [markdown]
# #### Medicky s enziniermi

# %%
df_match = df_personal[ df_personal['match']==1 ]
df_match.dropna(inplace=True)

# %%
df_match.columns
# Out:
# Index(['iid', 'pid', 'match', 'dec', 'career_c', 'career_c_partners', 'gender',
#        'gender_partners', '0_partners', '1_partners', '2_partners',
#        '3_partners', '4_partners', '5_partners', '6_partners', '7_partners',
#        '8_partners', '9_partners', '10_partners', '11_partners', '12_partners',
#        '13_partners', '14_partners', '15_partners', '16_partners', '0_me',
#        '1_me', '2_me', '3_me', '4_me', '5_me', '6_me', '7_me', '8_me', '9_me',
#        '10_me', '11_me', '12_me', '13_me', '14_me', '15_me', '16_me'],
#       dtype='object')

# %%
df_match = df_match.rename(columns={
    '0_partners' : 'lawyer',
    '1_partners' : 'academic',
    '2_partners' : 'psychologist',
    '3_partners' : 'doctor',
    '4_partners' : 'engineer',
    '5_partners' : 'entertainment',
    '6_partners' : 'bussiness',
    '7_partners' : 'real estate',
    '8_partners' : 'international',
    '9_partners' : 'undecided',
    '10_partners' : 'social work',
    '11_partners' : 'speach',
    '12_partners' : 'politics',
    '13_partners' : 'athletics',
    '14_partners' : 'other',
    '15_partners' : 'journalism',
    '16_partners' : 'architecture'
})

df_match = df_match.rename(columns={
    '3_me' : 'doctor_me',
    '4_me' : 'engineer_me',

})

# %%
atrs_partners = ['lawyer', 'academic', 'psychologist',
       'doctor', 
        'engineer', 'entertainment',
        'bussiness', 'real estate',
       'international', 'undecided', 'social work', 'speach', 'politics',
       'athletics', 'other', 'journalism', 'architecture'
]

atrs = [
        #'0_me','1_me', '2_me', '3_me',
        'doctor_me',
        'engineer_me'
        #'6_me', '7_me', '8_me', '9_me',
        #'10_me', '11_me', '12_me', '13_me', '14_me', '15_me'
]

# %%
df_match.columns
# Out:
# Index(['iid', 'pid', 'match', 'dec', 'career_c', 'career_c_partners', 'gender',
#        'gender_partners', 'lawyer', 'academic', 'psychologist', 'doctor',
#        'engineer', 'entertainment', 'bussiness', 'real estate',
#        'international', 'undecided', 'social work', 'speach', 'politics',
#        'athletics', 'other', 'journalism', 'architecture', '0_me', '1_me',
#        '2_me', 'doctor_me', 'engineer_me', '5_me', '6_me', '7_me', '8_me',
#        '9_me', '10_me', '11_me', '12_me', '13_me', '14_me', '15_me', '16_me'],
#       dtype='object')

# %%
# https://stats.stackexchange.com/questions/463324/logistic-regression-failed-in-statsmodel-but-works-in-sklearn-breast-cancer-dat

def calc_logit_carrer(df_match, x_vars, y_var):
    logit_mod = sm.GLM(df_match[y_var], df_match[x_vars], family=sm.families.NegativeBinomial()).fit()

    print(logit_mod.summary())

# %%
for i in atrs:
    print(i)
    x_vars = atrs_partners.copy()
    # x_vars.append(i)
    
    calc_logit_carrer(df_match.copy(), x_vars, i )
# Out:
# doctor_me
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              doctor_me   No. Observations:                 1296
# Model:                            GLM   Df Residuals:                     1280
# Model Family:        NegativeBinomial   Df Model:                           15
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -268.39
# Date:                Mon, 28 Mar 2022   Deviance:                       345.47
# Time:                        00:12:12   Pearson chi2:                 1.15e+03
# No. Iterations:                    19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# lawyer           -2.9178      0.419     -6.961      0.000      -3.739      -2.096
# academic         -2.8416      0.224    -12.658      0.000      -3.282      -2.402
# psychologist     -3.1355      0.722     -4.341      0.000      -4.551      -1.720
# doctor           -4.2195      1.007     -4.189      0.000      -6.194      -2.245
# engineer         -3.5264      1.015     -3.476      0.001      -5.515      -1.538
# entertainment    -2.9124      0.459     -6.342      0.000      -3.812      -2.012
# bussiness        -3.1987      0.273    -11.731      0.000      -3.733      -2.664
# real estate     -22.6261   2.03e+04     -0.001      0.999   -3.98e+04    3.97e+04
# international    -2.4953      0.368     -6.783      0.000      -3.216      -1.774
# undecided        -2.5177      0.465     -5.416      0.000      -3.429      -1.607
# social work      -2.7300      0.596     -4.582      0.000      -3.898      -1.562
# speach          -22.6261   4.97e+04     -0.000      1.000   -9.74e+04    9.73e+04
# politics         -1.7047      0.769     -2.218      0.027      -3.211      -0.198
# athletics       -22.6261   4.97e+04     -0.000      1.000   -9.74e+04    9.73e+04
# other            -2.6391      1.035     -2.550      0.011      -4.668      -0.610
# journalism      -22.6261   2.48e+04     -0.001      0.999   -4.87e+04    4.86e+04
# architecture           0          0        nan        nan           0           0
# =================================================================================
# engineer_me
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            engineer_me   No. Observations:                 1296
# Model:                            GLM   Df Residuals:                     1280
# Model Family:        NegativeBinomial   Df Model:                           15
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -200.40
# Date:                Mon, 28 Mar 2022   Deviance:                       267.71
# Time:                        00:12:12   Pearson chi2:                 1.18e+03
# No. Iterations:                    19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# lawyer           -4.0164      0.713     -5.630      0.000      -5.415      -2.618
# academic         -3.0529      0.248    -12.300      0.000      -3.539      -2.566
# psychologist     -2.7300      0.596     -4.582      0.000      -3.898      -1.562
# doctor           -3.5264      0.717     -4.915      0.000      -4.932      -2.120
# engineer         -2.8332      0.728     -3.894      0.000      -4.259      -1.407
# entertainment    -3.4232      0.587     -5.835      0.000      -4.573      -2.273
# bussiness        -3.8918      0.382    -10.193      0.000      -4.640      -3.144
# real estate     -22.9890   2.43e+04     -0.001      0.999   -4.77e+04    4.76e+04
# international    -2.7830      0.421     -6.615      0.000      -3.607      -1.958
# undecided        -4.1271      1.008     -4.094      0.000      -6.103      -2.151
# social work      -2.7300      0.596     -4.582      0.000      -3.898      -1.562
# speach          -22.9890   5.95e+04     -0.000      1.000   -1.17e+05    1.17e+05
# politics        -22.9890    1.8e+04     -0.001      0.999   -3.52e+04    3.52e+04
# athletics       -22.9890   5.95e+04     -0.000      1.000   -1.17e+05    1.17e+05
# other            -1.9459      0.756     -2.574      0.010      -3.428      -0.464
# journalism      -22.9890   2.98e+04     -0.001      0.999   -5.84e+04    5.83e+04
# architecture           0          0        nan        nan           0           0
# =================================================================================

# %%
N = 45
x, y = np.random.rand(2, N)
c = np.random.randint(1, 5, size=N)
s = np.random.randint(10, 220, size=N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c, s=s)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

# produce a legend with a cross section of sizes from the scatter
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

plt.show()

# %% [markdown]
# # Hypothesis 5

# %%
data_4 = data.copy()

# %%
df_personal = data_4[[
  'attr_me', 'sinc_me', 'fun_me', 'intel_me', 'amb_me', 'iid', 'pid', 'match', 'intel_me_partners', 'dec', 'dec_partner',
    'career','career_c', 'career_c_partners', 'gender', 'gender_partners',
    
    'sports','tvsports','exercise','dining','museums','art','hiking','gaming','clubbing',
    'reading','tv','theater','movies','concerts','music','shopping','yoga',
    
    'sports_partners','tvsports_partners','exercise_partners','dining_partners','museums_partners','art_partners','hiking_partners',
    'gaming_partners','clubbing_partners',
    'reading_partners','tv_partners','theater_partners','movies_partners','concerts_partners',
    'music_partners','shopping_partners','yoga_partners',
    
    
]]

colls = [
    'sports','tvsports','exercise','dining','museums','art','hiking','gaming','clubbing',
    'reading','tv','theater','movies','concerts','music','shopping','yoga',
    
    'sports_partners','tvsports_partners','exercise_partners','dining_partners','museums_partners','art_partners','hiking_partners',
    'gaming_partners','clubbing_partners',
    'reading_partners','tv_partners','theater_partners','movies_partners','concerts_partners',
    'music_partners','shopping_partners','yoga_partners'
]
# df_personal = df_personal[df_personal['match']==1]

# %%
atrs = [
    'sports','tvsports','exercise','dining','museums','art','hiking','gaming','clubbing',
    'reading','tv','theater','movies','concerts','music','shopping','yoga'
]

atrs_partners = [
    'sports_partners','tvsports_partners','exercise_partners','dining_partners',
    'museums_partners','art_partners','hiking_partners','gaming_partners','clubbing_partners',
    'reading_partners','tv_partners','theater_partners','movies_partners','concerts_partners',
    'music_partners','shopping_partners','yoga_partners'
]

for i in atrs:
    
    mean_i = df_personal[i].mean()
    df_personal[i] = df_personal[i] > mean_i
    df_personal[i+'_partners'] = df_personal[i+'_partners'] > mean_i

df_personal = df_personal.replace({True:1,False:0})

# %%
def calc_logit(df_match, x_vars, y_var ):

    logit_mod = sm.Logit( df_match[y_var], df_match[x_vars] )

    logit_res = logit_mod.fit()
    
#     x = df_match[prof_1]
#     y = df_match[prof_2]

#     xy = np.vstack([x,y])
#     z = gaussian_kde(xy)(xy)

#     fig, ax = plt.subplots()
    
#     ax.scatter(x, y, c=z, s=100)
#     ax.legend()
#     plt.show()

    print(logit_res.summary())

# %%
for i in atrs:
    print(i)
    x_vars = atrs_partners.copy()
    # x_vars.append(i)
    
    calc_logit(df_personal.copy(), x_vars, i )
# Out:
# sports
# Optimization terminated successfully.
#          Current function value: 0.680536
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 sports   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                 0.01132
# Time:                        23:22:57   Log-Likelihood:                -5701.5
# converged:                       True   LL-Null:                       -5766.8
# Covariance Type:            nonrobust   LLR p-value:                 5.061e-20
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners      -0.1566      0.049     -3.194      0.001      -0.253      -0.060
# tvsports_partners    -0.0595      0.050     -1.193      0.233      -0.157       0.038
# exercise_partners     0.0254      0.048      0.528      0.598      -0.069       0.120
# dining_partners       0.0436      0.050      0.872      0.383      -0.054       0.141
# museums_partners     -0.0865      0.070     -1.234      0.217      -0.224       0.051
# art_partners          0.0609      0.069      0.882      0.378      -0.074       0.196
# hiking_partners       0.1772      0.048      3.722      0.000       0.084       0.271
# gaming_partners      -0.2420      0.048     -5.024      0.000      -0.336      -0.148
# clubbing_partners    -0.0095      0.047     -0.204      0.839      -0.101       0.082
# reading_partners      0.0992      0.046      2.136      0.033       0.008       0.190
# tv_partners           0.1266      0.049      2.606      0.009       0.031       0.222
# theater_partners      0.2174      0.055      3.960      0.000       0.110       0.325
# movies_partners      -0.0287      0.053     -0.545      0.586      -0.132       0.075
# concerts_partners    -0.0462      0.056     -0.822      0.411      -0.157       0.064
# music_partners        0.0272      0.052      0.528      0.598      -0.074       0.128
# shopping_partners     0.1004      0.050      2.012      0.044       0.003       0.198
# yoga_partners         0.0905      0.047      1.907      0.057      -0.003       0.184
# =====================================================================================
# tvsports
# Optimization terminated successfully.
#          Current function value: 0.690053
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               tvsports   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.003335
# Time:                        23:22:57   Log-Likelihood:                -5781.3
# converged:                       True   LL-Null:                       -5800.6
# Covariance Type:            nonrobust   LLR p-value:                  0.001207
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners      -0.1502      0.049     -3.095      0.002      -0.245      -0.055
# tvsports_partners    -0.0640      0.049     -1.295      0.195      -0.161       0.033
# exercise_partners    -0.0161      0.048     -0.338      0.735      -0.109       0.077
# dining_partners      -0.0275      0.050     -0.556      0.579      -0.125       0.070
# museums_partners      0.0199      0.070      0.285      0.775      -0.117       0.157
# art_partners         -0.0341      0.069     -0.497      0.619      -0.169       0.100
# hiking_partners       0.0687      0.047      1.455      0.146      -0.024       0.161
# gaming_partners      -0.1254      0.048     -2.629      0.009      -0.219      -0.032
# clubbing_partners     0.0677      0.046      1.465      0.143      -0.023       0.158
# reading_partners      0.0121      0.046      0.263      0.793      -0.078       0.103
# tv_partners           0.0259      0.048      0.538      0.590      -0.068       0.120
# theater_partners      0.0432      0.055      0.790      0.429      -0.064       0.150
# movies_partners      -0.0322      0.052     -0.616      0.538      -0.135       0.070
# concerts_partners    -0.0153      0.056     -0.274      0.784      -0.124       0.094
# music_partners       -0.0565      0.051     -1.106      0.269      -0.157       0.044
# shopping_partners     0.1170      0.049      2.367      0.018       0.020       0.214
# yoga_partners         0.0371      0.047      0.789      0.430      -0.055       0.129
# =====================================================================================
# exercise
# Optimization terminated successfully.
#          Current function value: 0.692299
#          Iterations 3
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               exercise   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.001137
# Time:                        23:22:57   Log-Likelihood:                -5800.1
# converged:                       True   LL-Null:                       -5806.7
# Covariance Type:            nonrobust   LLR p-value:                    0.6581
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.0353      0.048      0.728      0.467      -0.060       0.130
# tvsports_partners    -0.0254      0.049     -0.514      0.607      -0.122       0.071
# exercise_partners    -0.0719      0.047     -1.514      0.130      -0.165       0.021
# dining_partners       0.0123      0.049      0.249      0.804      -0.085       0.109
# museums_partners      0.0072      0.070      0.103      0.918      -0.129       0.144
# art_partners         -0.0068      0.068     -0.100      0.920      -0.141       0.127
# hiking_partners       0.0222      0.047      0.472      0.637      -0.070       0.114
# gaming_partners      -0.0206      0.048     -0.434      0.665      -0.114       0.073
# clubbing_partners     0.0546      0.046      1.185      0.236      -0.036       0.145
# reading_partners     -0.0420      0.046     -0.914      0.361      -0.132       0.048
# tv_partners           0.0334      0.048      0.695      0.487      -0.061       0.127
# theater_partners     -0.0347      0.054     -0.636      0.524      -0.141       0.072
# movies_partners       0.0070      0.052      0.133      0.894      -0.095       0.109
# concerts_partners    -0.0399      0.056     -0.718      0.473      -0.149       0.069
# music_partners        0.0833      0.051      1.633      0.102      -0.017       0.183
# shopping_partners    -0.0950      0.049     -1.924      0.054      -0.192       0.002
# yoga_partners         0.0191      0.047      0.407      0.684      -0.073       0.111
# =====================================================================================
# dining
# Optimization terminated successfully.
#          Current function value: 0.669913
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 dining   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:              -0.0001953
# Time:                        23:22:57   Log-Likelihood:                -5612.5
# converged:                       True   LL-Null:                       -5611.4
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1972      0.049      3.985      0.000       0.100       0.294
# tvsports_partners     0.0667      0.051      1.320      0.187      -0.032       0.166
# exercise_partners     0.0330      0.049      0.679      0.497      -0.062       0.128
# dining_partners       0.0446      0.051      0.883      0.377      -0.054       0.144
# museums_partners     -0.0958      0.071     -1.349      0.177      -0.235       0.043
# art_partners          0.2122      0.070      3.040      0.002       0.075       0.349
# hiking_partners      -0.0304      0.048     -0.631      0.528      -0.125       0.064
# gaming_partners       0.1242      0.049      2.549      0.011       0.029       0.220
# clubbing_partners     0.0953      0.047      2.023      0.043       0.003       0.188
# reading_partners      0.0618      0.047      1.315      0.189      -0.030       0.154
# tv_partners          -0.0437      0.049     -0.890      0.373      -0.140       0.053
# theater_partners     -0.1438      0.056     -2.576      0.010      -0.253      -0.034
# movies_partners       0.1274      0.053      2.390      0.017       0.023       0.232
# concerts_partners     0.0454      0.057      0.801      0.423      -0.066       0.157
# music_partners        0.0805      0.052      1.546      0.122      -0.022       0.182
# shopping_partners    -0.1155      0.050     -2.287      0.022      -0.214      -0.016
# yoga_partners         0.0380      0.048      0.793      0.428      -0.056       0.132
# =====================================================================================
# museums
# Optimization terminated successfully.
#          Current function value: 0.647573
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                museums   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:               -0.003711
# Time:                        23:22:57   Log-Likelihood:                -5425.4
# converged:                       True   LL-Null:                       -5405.3
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.2514      0.051      4.970      0.000       0.152       0.351
# tvsports_partners     0.1298      0.052      2.511      0.012       0.028       0.231
# exercise_partners     0.0480      0.050      0.967      0.334      -0.049       0.145
# dining_partners       0.0426      0.052      0.825      0.409      -0.059       0.144
# museums_partners     -0.1515      0.073     -2.088      0.037      -0.294      -0.009
# art_partners          0.1961      0.071      2.750      0.006       0.056       0.336
# hiking_partners       0.0528      0.049      1.073      0.283      -0.044       0.149
# gaming_partners       0.2174      0.050      4.361      0.000       0.120       0.315
# clubbing_partners     0.0169      0.048      0.351      0.726      -0.078       0.112
# reading_partners      0.1894      0.048      3.937      0.000       0.095       0.284
# tv_partners          -0.0105      0.050     -0.209      0.835      -0.109       0.088
# theater_partners     -0.0929      0.057     -1.628      0.104      -0.205       0.019
# movies_partners       0.1817      0.055      3.334      0.001       0.075       0.289
# concerts_partners    -0.0702      0.058     -1.210      0.226      -0.184       0.043
# music_partners        0.1060      0.053      1.994      0.046       0.002       0.210
# shopping_partners    -0.0707      0.052     -1.371      0.170      -0.172       0.030
# yoga_partners         0.0073      0.049      0.149      0.882      -0.089       0.104
# =====================================================================================
# art
# Optimization terminated successfully.
#          Current function value: 0.675602
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    art   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.002620
# Time:                        23:22:57   Log-Likelihood:                -5660.2
# converged:                       True   LL-Null:                       -5675.1
# Covariance Type:            nonrobust   LLR p-value:                   0.01940
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.2593      0.049      5.268      0.000       0.163       0.356
# tvsports_partners     0.0436      0.050      0.869      0.385      -0.055       0.142
# exercise_partners    -0.0198      0.048     -0.410      0.682      -0.114       0.075
# dining_partners       0.0726      0.050      1.445      0.148      -0.026       0.171
# museums_partners     -0.0328      0.071     -0.463      0.643      -0.171       0.106
# art_partners          0.0832      0.070      1.197      0.231      -0.053       0.220
# hiking_partners      -0.0560      0.048     -1.170      0.242      -0.150       0.038
# gaming_partners       0.1243      0.048      2.567      0.010       0.029       0.219
# clubbing_partners     0.0666      0.047      1.421      0.155      -0.025       0.158
# reading_partners      0.0687      0.047      1.468      0.142      -0.023       0.160
# tv_partners          -0.0400      0.049     -0.820      0.412      -0.136       0.056
# theater_partners     -0.1259      0.056     -2.267      0.023      -0.235      -0.017
# movies_partners       0.1674      0.053      3.155      0.002       0.063       0.271
# concerts_partners     0.0125      0.056      0.221      0.825      -0.098       0.123
# music_partners        0.0306      0.052      0.592      0.554      -0.071       0.132
# shopping_partners    -0.0571      0.050     -1.137      0.255      -0.155       0.041
# yoga_partners        -0.0342      0.048     -0.718      0.473      -0.128       0.059
# =====================================================================================
# hiking
# Optimization terminated successfully.
#          Current function value: 0.686455
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 hiking   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.001767
# Time:                        23:22:57   Log-Likelihood:                -5751.1
# converged:                       True   LL-Null:                       -5761.3
# Covariance Type:            nonrobust   LLR p-value:                    0.2042
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1520      0.049      3.123      0.002       0.057       0.247
# tvsports_partners     0.0303      0.050      0.610      0.542      -0.067       0.128
# exercise_partners     0.0417      0.048      0.872      0.383      -0.052       0.135
# dining_partners       0.0270      0.050      0.543      0.587      -0.070       0.124
# museums_partners      0.0814      0.070      1.162      0.245      -0.056       0.219
# art_partners         -0.0209      0.069     -0.304      0.761      -0.156       0.114
# hiking_partners       0.0207      0.047      0.437      0.662      -0.072       0.113
# gaming_partners       0.1214      0.048      2.537      0.011       0.028       0.215
# clubbing_partners    -0.0817      0.046     -1.761      0.078      -0.173       0.009
# reading_partners      0.0602      0.046      1.302      0.193      -0.030       0.151
# tv_partners          -0.0050      0.048     -0.103      0.918      -0.100       0.090
# theater_partners     -0.0923      0.055     -1.683      0.092      -0.200       0.015
# movies_partners       0.0438      0.053      0.834      0.405      -0.059       0.147
# concerts_partners     0.0232      0.056      0.415      0.678      -0.086       0.133
# music_partners        0.0321      0.051      0.626      0.531      -0.068       0.133
# shopping_partners    -0.0675      0.050     -1.360      0.174      -0.165       0.030
# yoga_partners        -0.0358      0.047     -0.760      0.447      -0.128       0.057
# =====================================================================================
# gaming
# Optimization terminated successfully.
#          Current function value: 0.688701
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 gaming   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.005014
# Time:                        23:22:58   Log-Likelihood:                -5769.9
# converged:                       True   LL-Null:                       -5799.0
# Covariance Type:            nonrobust   LLR p-value:                 1.069e-06
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners      -0.2302      0.049     -4.738      0.000      -0.325      -0.135
# tvsports_partners    -0.0591      0.050     -1.193      0.233      -0.156       0.038
# exercise_partners     0.0120      0.048      0.252      0.801      -0.081       0.105
# dining_partners      -0.0203      0.050     -0.410      0.682      -0.118       0.077
# museums_partners      0.0597      0.070      0.854      0.393      -0.077       0.197
# art_partners         -0.0589      0.069     -0.857      0.391      -0.194       0.076
# hiking_partners       0.0806      0.047      1.705      0.088      -0.012       0.173
# gaming_partners      -0.1060      0.048     -2.219      0.026      -0.200      -0.012
# clubbing_partners     0.0330      0.046      0.714      0.475      -0.058       0.124
# reading_partners      0.0162      0.046      0.350      0.726      -0.074       0.107
# tv_partners           0.0968      0.048      2.009      0.045       0.002       0.191
# theater_partners      0.0934      0.055      1.707      0.088      -0.014       0.201
# movies_partners      -0.1488      0.052     -2.836      0.005      -0.252      -0.046
# concerts_partners     0.0039      0.056      0.070      0.944      -0.105       0.113
# music_partners       -0.0236      0.051     -0.461      0.645      -0.124       0.077
# shopping_partners     0.0760      0.050      1.536      0.125      -0.021       0.173
# yoga_partners         0.0587      0.047      1.249      0.212      -0.033       0.151
# =====================================================================================
# clubbing
# Optimization terminated successfully.
#          Current function value: 0.676588
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               clubbing   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.001666
# Time:                        23:22:58   Log-Likelihood:                -5668.5
# converged:                       True   LL-Null:                       -5677.9
# Covariance Type:            nonrobust   LLR p-value:                    0.2730
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.0098      0.049      0.199      0.842      -0.087       0.106
# tvsports_partners     0.1323      0.050      2.636      0.008       0.034       0.231
# exercise_partners     0.0621      0.048      1.288      0.198      -0.032       0.157
# dining_partners       0.0475      0.050      0.947      0.344      -0.051       0.146
# museums_partners     -0.1963      0.071     -2.778      0.005      -0.335      -0.058
# art_partners          0.2152      0.069      3.101      0.002       0.079       0.351
# hiking_partners      -0.1074      0.048     -2.243      0.025      -0.201      -0.014
# gaming_partners       0.1075      0.048      2.222      0.026       0.013       0.202
# clubbing_partners     0.1838      0.047      3.935      0.000       0.092       0.275
# reading_partners      0.0698      0.047      1.494      0.135      -0.022       0.161
# tv_partners          -0.0597      0.049     -1.225      0.221      -0.155       0.036
# theater_partners      0.0460      0.055      0.832      0.405      -0.062       0.154
# movies_partners       0.0681      0.053      1.285      0.199      -0.036       0.172
# concerts_partners    -0.0590      0.056     -1.045      0.296      -0.170       0.052
# music_partners        0.0292      0.052      0.564      0.573      -0.072       0.131
# shopping_partners    -0.0640      0.050     -1.277      0.201      -0.162       0.034
# yoga_partners         0.1304      0.048      2.733      0.006       0.037       0.224
# =====================================================================================
# reading
# Optimization terminated successfully.
#          Current function value: 0.671473
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                reading   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:               0.0008169
# Time:                        23:22:58   Log-Likelihood:                -5625.6
# converged:                       True   LL-Null:                       -5630.2
# Covariance Type:            nonrobust   LLR p-value:                    0.9050
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.2098      0.049      4.247      0.000       0.113       0.307
# tvsports_partners     0.0633      0.050      1.256      0.209      -0.036       0.162
# exercise_partners    -0.0154      0.048     -0.318      0.750      -0.110       0.080
# dining_partners       0.0149      0.050      0.296      0.767      -0.084       0.114
# museums_partners      0.1068      0.071      1.501      0.133      -0.033       0.246
# art_partners          0.0305      0.070      0.436      0.663      -0.107       0.168
# hiking_partners       0.0353      0.048      0.735      0.462      -0.059       0.129
# gaming_partners       0.1325      0.049      2.726      0.006       0.037       0.228
# clubbing_partners     0.0549      0.047      1.167      0.243      -0.037       0.147
# reading_partners      0.1565      0.047      3.336      0.001       0.065       0.249
# tv_partners          -0.0783      0.049     -1.597      0.110      -0.174       0.018
# theater_partners     -0.1363      0.056     -2.444      0.015      -0.246      -0.027
# movies_partners       0.0770      0.053      1.446      0.148      -0.027       0.181
# concerts_partners    -0.0302      0.057     -0.532      0.595      -0.141       0.081
# music_partners        0.0925      0.052      1.780      0.075      -0.009       0.194
# shopping_partners    -0.0429      0.050     -0.851      0.395      -0.142       0.056
# yoga_partners        -0.0312      0.048     -0.651      0.515      -0.125       0.063
# =====================================================================================
# tv
# Optimization terminated successfully.
#          Current function value: 0.689500
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                     tv   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.005222
# Time:                        23:22:58   Log-Likelihood:                -5776.6
# converged:                       True   LL-Null:                       -5807.0
# Covariance Type:            nonrobust   LLR p-value:                 4.062e-07
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1386      0.049      2.856      0.004       0.044       0.234
# tvsports_partners     0.0263      0.049      0.531      0.595      -0.071       0.123
# exercise_partners     0.0342      0.048      0.719      0.472      -0.059       0.128
# dining_partners      -0.0439      0.050     -0.887      0.375      -0.141       0.053
# museums_partners      0.0216      0.070      0.310      0.757      -0.115       0.158
# art_partners          0.1172      0.069      1.706      0.088      -0.017       0.252
# hiking_partners      -0.0596      0.047     -1.263      0.207      -0.152       0.033
# gaming_partners       0.1930      0.048      4.041      0.000       0.099       0.287
# clubbing_partners    -0.0241      0.046     -0.520      0.603      -0.115       0.067
# reading_partners     -0.0845      0.046     -1.832      0.067      -0.175       0.006
# tv_partners          -0.0787      0.048     -1.634      0.102      -0.173       0.016
# theater_partners     -0.1521      0.055     -2.785      0.005      -0.259      -0.045
# movies_partners       0.0237      0.052      0.452      0.651      -0.079       0.126
# concerts_partners    -0.0391      0.056     -0.702      0.483      -0.148       0.070
# music_partners        0.0242      0.051      0.472      0.637      -0.076       0.124
# shopping_partners    -0.0453      0.049     -0.916      0.359      -0.142       0.052
# yoga_partners        -0.0450      0.047     -0.956      0.339      -0.137       0.047
# =====================================================================================
# theater
# Optimization terminated successfully.
#          Current function value: 0.665535
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                theater   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                 0.01016
# Time:                        23:22:58   Log-Likelihood:                -5575.9
# converged:                       True   LL-Null:                       -5633.1
# Covariance Type:            nonrobust   LLR p-value:                 6.254e-17
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.4125      0.050      8.320      0.000       0.315       0.510
# tvsports_partners     0.0627      0.051      1.238      0.216      -0.037       0.162
# exercise_partners    -0.0002      0.049     -0.004      0.997      -0.096       0.095
# dining_partners       0.0051      0.051      0.099      0.921      -0.095       0.105
# museums_partners      0.0551      0.072      0.768      0.442      -0.085       0.196
# art_partners          0.1109      0.070      1.576      0.115      -0.027       0.249
# hiking_partners      -0.1120      0.048     -2.312      0.021      -0.207      -0.017
# gaming_partners       0.2730      0.049      5.577      0.000       0.177       0.369
# clubbing_partners     0.1277      0.047      2.697      0.007       0.035       0.221
# reading_partners      0.0010      0.047      0.022      0.983      -0.092       0.094
# tv_partners          -0.0860      0.049     -1.745      0.081      -0.183       0.011
# theater_partners     -0.2584      0.056     -4.595      0.000      -0.369      -0.148
# movies_partners       0.1308      0.054      2.435      0.015       0.025       0.236
# concerts_partners     0.0810      0.057      1.415      0.157      -0.031       0.193
# music_partners        0.0644      0.052      1.229      0.219      -0.038       0.167
# shopping_partners    -0.1857      0.051     -3.662      0.000      -0.285      -0.086
# yoga_partners        -0.0670      0.048     -1.392      0.164      -0.161       0.027
# =====================================================================================
# movies
# Optimization terminated successfully.
#          Current function value: 0.651237
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 movies   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:               -0.005773
# Time:                        23:22:58   Log-Likelihood:                -5456.1
# converged:                       True   LL-Null:                       -5424.7
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.2413      0.050      4.785      0.000       0.142       0.340
# tvsports_partners     0.1145      0.052      2.224      0.026       0.014       0.215
# exercise_partners     0.0539      0.049      1.089      0.276      -0.043       0.151
# dining_partners       0.0477      0.051      0.928      0.353      -0.053       0.149
# museums_partners     -0.0410      0.072     -0.568      0.570      -0.182       0.100
# art_partners          0.2327      0.071      3.277      0.001       0.094       0.372
# hiking_partners       0.0171      0.049      0.349      0.727      -0.079       0.113
# gaming_partners       0.0971      0.050      1.956      0.050      -0.000       0.194
# clubbing_partners     0.0857      0.048      1.783      0.075      -0.009       0.180
# reading_partners      0.0801      0.048      1.672      0.095      -0.014       0.174
# tv_partners          -0.0323      0.050     -0.645      0.519      -0.130       0.066
# theater_partners     -0.1386      0.057     -2.436      0.015      -0.250      -0.027
# movies_partners       0.1450      0.054      2.674      0.008       0.039       0.251
# concerts_partners     0.0012      0.058      0.021      0.984      -0.112       0.114
# music_partners        0.1225      0.053      2.312      0.021       0.019       0.226
# shopping_partners    -0.0183      0.051     -0.357      0.721      -0.119       0.082
# yoga_partners        -0.0417      0.049     -0.853      0.394      -0.138       0.054
# =====================================================================================
# concerts
# Optimization terminated successfully.
#          Current function value: 0.675056
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               concerts   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:               -0.001001
# Time:                        23:22:58   Log-Likelihood:                -5655.6
# converged:                       True   LL-Null:                       -5650.0
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1581      0.049      3.210      0.001       0.062       0.255
# tvsports_partners     0.0507      0.050      1.009      0.313      -0.048       0.149
# exercise_partners     0.0225      0.048      0.465      0.642      -0.072       0.117
# dining_partners       0.0887      0.050      1.766      0.077      -0.010       0.187
# museums_partners     -0.1350      0.071     -1.909      0.056      -0.274       0.004
# art_partners          0.1343      0.069      1.933      0.053      -0.002       0.270
# hiking_partners      -0.0040      0.048     -0.084      0.933      -0.098       0.090
# gaming_partners       0.1239      0.048      2.557      0.011       0.029       0.219
# clubbing_partners     0.0061      0.047      0.129      0.897      -0.086       0.098
# reading_partners      0.0498      0.047      1.065      0.287      -0.042       0.142
# tv_partners          -0.0642      0.049     -1.316      0.188      -0.160       0.031
# theater_partners     -0.0369      0.055     -0.666      0.506      -0.146       0.072
# movies_partners       0.0875      0.053      1.649      0.099      -0.017       0.191
# concerts_partners     0.0569      0.056      1.009      0.313      -0.054       0.167
# music_partners        0.1290      0.052      2.495      0.013       0.028       0.230
# shopping_partners    -0.0699      0.050     -1.393      0.164      -0.168       0.028
# yoga_partners         0.0199      0.048      0.416      0.677      -0.074       0.113
# =====================================================================================
# music
# Optimization terminated successfully.
#          Current function value: 0.671922
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  music   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:               -0.001879
# Time:                        23:22:59   Log-Likelihood:                -5629.4
# converged:                       True   LL-Null:                       -5618.8
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1247      0.049      2.524      0.012       0.028       0.222
# tvsports_partners    -0.0114      0.050     -0.226      0.821      -0.110       0.087
# exercise_partners     0.0951      0.048      1.963      0.050       0.000       0.190
# dining_partners       0.0490      0.050      0.974      0.330      -0.050       0.148
# museums_partners     -0.0316      0.071     -0.446      0.656      -0.170       0.107
# art_partners          0.0446      0.070      0.640      0.522      -0.092       0.181
# hiking_partners       0.0248      0.048      0.516      0.606      -0.069       0.119
# gaming_partners       0.0797      0.049      1.640      0.101      -0.016       0.175
# clubbing_partners     0.0135      0.047      0.286      0.775      -0.079       0.106
# reading_partners      0.0969      0.047      2.067      0.039       0.005       0.189
# tv_partners          -0.0229      0.049     -0.467      0.641      -0.119       0.073
# theater_partners     -0.0751      0.056     -1.349      0.177      -0.184       0.034
# movies_partners       0.0840      0.053      1.580      0.114      -0.020       0.188
# concerts_partners     0.0913      0.057      1.616      0.106      -0.019       0.202
# music_partners        0.0746      0.052      1.437      0.151      -0.027       0.176
# shopping_partners     0.0376      0.050      0.746      0.456      -0.061       0.136
# yoga_partners         0.0186      0.048      0.387      0.698      -0.075       0.112
# =====================================================================================
# shopping
# Optimization terminated successfully.
#          Current function value: 0.685531
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               shopping   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.009122
# Time:                        23:22:59   Log-Likelihood:                -5743.4
# converged:                       True   LL-Null:                       -5796.2
# Covariance Type:            nonrobust   LLR p-value:                 2.871e-15
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1731      0.049      3.554      0.000       0.078       0.269
# tvsports_partners     0.1441      0.050      2.903      0.004       0.047       0.241
# exercise_partners    -0.0477      0.048     -0.996      0.319      -0.141       0.046
# dining_partners      -0.0394      0.050     -0.790      0.429      -0.137       0.058
# museums_partners     -0.1137      0.070     -1.619      0.105      -0.251       0.024
# art_partners          0.2284      0.069      3.305      0.001       0.093       0.364
# hiking_partners      -0.1035      0.047     -2.182      0.029      -0.196      -0.011
# gaming_partners       0.1996      0.048      4.166      0.000       0.106       0.293
# clubbing_partners     0.0182      0.046      0.392      0.695      -0.073       0.109
# reading_partners     -0.0287      0.046     -0.619      0.536      -0.120       0.062
# tv_partners          -0.0675      0.048     -1.396      0.163      -0.162       0.027
# theater_partners     -0.2226      0.055     -4.054      0.000      -0.330      -0.115
# movies_partners       0.1147      0.053      2.181      0.029       0.012       0.218
# concerts_partners    -0.0486      0.056     -0.866      0.386      -0.158       0.061
# music_partners        0.1201      0.051      2.336      0.019       0.019       0.221
# shopping_partners    -0.1522      0.050     -3.066      0.002      -0.250      -0.055
# yoga_partners        -0.0303      0.047     -0.642      0.521      -0.123       0.062
# =====================================================================================
# yoga
# Optimization terminated successfully.
#          Current function value: 0.683753
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   yoga   No. Observations:                 8378
# Model:                          Logit   Df Residuals:                     8361
# Method:                           MLE   Df Model:                           16
# Date:                Sat, 26 Mar 2022   Pseudo R-squ.:                0.005770
# Time:                        23:22:59   Log-Likelihood:                -5728.5
# converged:                       True   LL-Null:                       -5761.7
# Covariance Type:            nonrobust   LLR p-value:                 4.073e-08
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# sports_partners       0.1196      0.049      2.447      0.014       0.024       0.215
# tvsports_partners    -0.0076      0.050     -0.152      0.879      -0.105       0.090
# exercise_partners    -0.0200      0.048     -0.418      0.676      -0.114       0.074
# dining_partners       0.0318      0.050      0.639      0.523      -0.066       0.130
# museums_partners     -0.0136      0.070     -0.195      0.846      -0.151       0.124
# art_partners          0.0227      0.069      0.329      0.742      -0.112       0.158
# hiking_partners      -0.1386      0.047     -2.920      0.003      -0.232      -0.046
# gaming_partners       0.1276      0.048      2.659      0.008       0.034       0.222
# clubbing_partners     0.0526      0.046      1.131      0.258      -0.039       0.144
# reading_partners     -0.0765      0.046     -1.651      0.099      -0.167       0.014
# tv_partners          -0.1069      0.048     -2.209      0.027      -0.202      -0.012
# theater_partners     -0.1499      0.055     -2.736      0.006      -0.257      -0.043
# movies_partners      -0.0372      0.053     -0.707      0.479      -0.140       0.066
# concerts_partners     0.0543      0.056      0.969      0.332      -0.056       0.164
# music_partners        0.0079      0.051      0.154      0.877      -0.093       0.109
# shopping_partners    -0.1389      0.050     -2.793      0.005      -0.236      -0.041
# yoga_partners        -0.0912      0.047     -1.927      0.054      -0.184       0.002
# =====================================================================================
